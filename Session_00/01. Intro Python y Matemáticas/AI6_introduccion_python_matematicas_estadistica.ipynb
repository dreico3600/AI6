# %% [markdown]
# <a href="https://colab.research.google.com/github/dreico3600/AI6/blob/main/Session_00/01.%20Intro%20Python%20y%20Matem%C3%A1ticas/AI6_introduccion_python_matematicas_estadistica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # introducción a Python

# %% [markdown]
# ![3-47.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Python es un lenguaje de programación libre que es interpretado de tipado dinámico cuya filosofía hace hincapié en una sintaxis que favorezca un código legible. Es uno de los lenguajes con mayor demanda en el mercado.

# %% [markdown]
# ## Usos de python:
#
#
# *   Inteligencia Artificial (AI)
# *   Big Data
# *   Data Science
# *   Iot

# %% [markdown]
# # Aprendiendo python

# %% [markdown]
# ## Que es una variable
#
# Variable es algo que puede cambiar, que no es constante y su almacenaje se encuentra en la memoria principal del computador (CPU) y esta tiene que ser asociada a un nombre.
#
# **Ejemplo**

# %%
# Declaración de una variable y la asociación  a un nombre
nombre = 'David'

# %%
# Espacio de memoria en la que se encuentra
hex(id(nombre))
# Out:
# '0x7fc283018830'

# %% [markdown]
# Restricciones sobre los nombres de las variables
#
#
# *   No debe empezar ni contener carácteres especiales
# *   No puede empezar por números
# *   **No pueden ser llamadas igual que las palabras claves reservadas en python**
# *   No puede contener espacios

# %%
#óla = 1
#1ola = 1
#def = 1
#var 1 = 1

# %% [markdown]
# ## Recomendaciones antes de empezar
#
# Existe una norma para la escritura de código python se llama PEP 8 en donde te señalan algunas buenas practicas a seguir. Las más importantes son:
#
# 1.   Las variables de una sola palabra se escriben en minúscula
# 2.   Si la variables se comporta de 2 o más palabras se debe escribir en camel case: **nombreVariable** o pascal case: **NombreVariable**
# 3.   Las funciones se escriben en snake case: **nombre_funcion**
#
# **Es preferible escribir todo el código y comentarios en ingles**

# %% [markdown]
# ## Palabras clave
#
# Se deben evitar usar alguno de los siguientes nombres de la lista

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %% [markdown]
# ## Ejemplos de uso

# %% [markdown]
# ## mnemónico
# Una ayuda para memorizar. A menudo damos nombres mnemónicos a las variables para ayudarnos a recordar qué está almacenado en ellas

# %% [markdown]
# ![Screenshot_2.png](data:image/png;base64,...)

# %%
name = 'Kevin David Farinango'
firstName, middleName, lastName = name.split()

# %%
#name.split()

# %%
#first_name
#middle_name
#last_name

# %% [markdown]
# ## Variables mas usadas
#
# 1.   Cadena
# 2.   Números
# 3.   Lista
# 4.   Tupla
# 5.   Diccionario
#
# **Nota:** Usaremos type para saber de que tipo es el objeto o la variable con la cual estamos trabajando

# %%
# Cadena de caracteres
print(f'{name} es un tipo de dato {type(name)}')
# Out:
# Kevin David Farinango es un tipo de dato <class 'str'>

# %%
stature = 1.65
print(f'{stature} es un tipo de dato {type(stature)}')
# Out:
# 1.65 es un tipo de dato <class 'float'>

# %%
dateBirth = '24/01/97'
print(f'{dateBirth} es de tipo {type(dateBirth)}')

# Plus date
from datetime import datetime

dateBirth_2 = datetime.strptime(dateBirth, '%d/%m/%y')
print(f'{dateBirth_2} es de tipo {type(dateBirth_2)}')
# Out:
# 24/01/97 es de tipo <class 'str'>
# 1997-01-24 00:00:00 es de tipo <class 'datetime.datetime'>

# %%
today = datetime.now()      
differenceBeteweenDays = today - dateBirth_2  
years = int(differenceBeteweenDays.days / 365)
print(f"{years} Años es de tipo {type(years)}")
# Out:
# 24 Años es de tipo <class 'int'>

# %%
informationList = [name, stature, years]
print(f'{informationList} es un tipo de dato {type(informationList)}')

informationList_2 = (name, stature, years, )
print(f'{informationList_2} es un tipo de dato {type(informationList_2)}')
# Out:
# ['Kevin David Farinango', 1.65, 24] es un tipo de dato <class 'list'>
# ('Kevin David Farinango', 1.65, 24) es un tipo de dato <class 'tuple'>

# %%
informationList.append('Avenida Siempreviva 742')
informationList.append('Avenida Siempreviva 742')

# %%
informationList
# Out:
# ['Kevin David Farinango',
#  1.65,
#  24,
#  'Avenida Siempreviva 742',
#  'Avenida Siempreviva 742']

# %%
del informationList[-1]

# %%
informationList
# Out:
# ['Kevin David Farinango', 1.65, 24, 'Avenida Siempreviva 742']

# %%
#Principio al fin
informationList[:]

#Mismo proceso para la tupla 
#informationList_2[:]
# Out:
# ['Kevin David Farinango', 1.65, 24, 'Avenida Siempreviva 742']

# %%
#Hasta el penultimo elemento
informationList[:-1]

#Mismo proceso para la tupla 
#informationList_2[:-1]
# Out:
# ['Kevin David Farinango', 1.65, 24]

# %%
#Poner al reves la lista
informationList[::-1]

#Mismo proceso para la tupla 
#informationList_2[::-1]
# Out:
# ['Avenida Siempreviva 742', 24, 1.65, 'Kevin David Farinango']

# %%
#Saltando de uno
informationList[::2]

#Mismo proceso para la tupla 
#informationList_2[::2]
# Out:
# ['Kevin David Farinango', 24]

# %%
[print(type(element)) for element in informationList ]
# Out:
# <class 'str'>
# <class 'float'>
# <class 'int'>
# <class 'str'>
# [None, None, None, None]

# %%
asuskfDict = {'first_name':firstName, 'middle_name':middleName, 'last_name':lastName, 'stature':stature, 'years':years}

# %%
asuskfDict['first_name']
# Out:
# 'Kevin'

# %% [markdown]
# # Operaciones artiméticas

# %%
# Suma
1 +2
# Out:
# 3

# %%
1.0 +2
# Out:
# 3.0

# %% [markdown]
# **Observación:** Al combinar un número entero con un flotante el resultado es un flotante

# %%
# Producto
8 *6
# Out:
# 48

# %%
8.*6
# Out:
# 48.0

# %%
# División
6 / 6
# Out:
# 1.0

# %% [markdown]
# **Observación:** El resultado de la división es un flotante **cambia en versiones de Python**

# %%
# Cociente 
10 //3
# Out:
# 3

# %%
10 % 3
# Out:
# 1

# %%
# Potencia
5 ** 3
# Out:
# 125

# %%
5. **3
# Out:
# 125.0

# %% [markdown]
# Para calcular la potencia $n-ésima$ de un número, también podemos usar `pow()`

# %%
pow(5, 3)
# Out:
# 125

# %% [markdown]
# ## Orden de las operaciones aritméticas
#
# El orden en que se llevan a cabo las operaciones aritméticas en `Python` es el siguiente:
#
# - Primero se calcula lo que se halla entre paréntesis.
# - A continuación, las potencias.
# - Después, productos y divisiones. En caso de haber varias, el orden que se sigue es de izquierda a derecha.
# - Finalmente, sumas y restas. En caso de haber varias, el orden que se sigue es de izquierda a derecha.

# %%
6 + 2 * 8 / 4 - 2 ** 3
# Out:
# 2.0

# %%
(6 + 2) * (8 / (4 - 2)) ** 3
# Out:
# 512.0

# %%
(6 + 2) * 8 / (4 - 2) ** 3
# Out:
# 8.0

# %% [markdown]
# **Observación.** El uso de los paréntesis puede cambiar completamente el resultado. No conviene abusar de ellos, aunque es mejor que sobren, ya que ayudan a entender el orden en que se van a llevar a cabo las operaciones.

# %% [markdown]
# # Estadística
# Muestreo estadístico
#
#
#
# *   Población : Todos los sujetos
# *   Muestra: Subconjunto representativo

# %% [markdown]
# ## Tipos de muestreo:
#
#
# 1.   Aleatorio con reposición (Muerstra aleatoria simple **m.a.s**): Seleccionar una muestra de forma equiprobable (La equiprobabilidad es una situación o evento en la teoría de probabilidad, en que todos los resultados posibles son igualmente probables.​ )

# %% [markdown]
# ![Screenshot_1.png](data:image/png;base64,...)

# %%
from numpy import random as rd
numberElments = 10
numberSize = 8 
ary = list(range(numberElments))

# %%
rd.choice(ary, size=numberSize, replace=True)
# Out:
# array([2, 7, 5, 7, 8, 2, 1, 9])

# %% [markdown]
# 2.   Aleatorio sin reposición: No es equiprobable

# %%
rd.choice(ary, size=numberSize, replace=False)
# Out:
# array([9, 8, 6, 4, 0, 7, 3, 1])

# %% [markdown]
# # Fuentes
#
#
# *   https://www.programoergosum.com/cursos-online/raspberry-pi/244-iniciacion-a-python-en-raspberry-pi/que-es-python
# *   https://j2logo.com/python/tutorial/variables-python/
